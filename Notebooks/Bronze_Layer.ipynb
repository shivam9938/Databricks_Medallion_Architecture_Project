# %% [markdown]
#  **Creating parameters through widgets**

# %%
dbutils.widgets.text("file_name","")
p_file=dbutils.widgets.get("file_name")

# %% [markdown]
# #  Data Autoloader Ingestion

# %%
df = spark.readStream.format('cloudFiles').option("cloudFiles.format", "parquet").option("cloudFiles.schemaLocation", f"abfss://bronze@dbproject.dfs.core.windows.net/checkpoint_{p_file}").load(f'abfss://source@dbproject.dfs.core.windows.net/{p_file}')

a=df.writeStream.format("parquet").outputMode('append').option("checkpointLocation", f"abfss://bronze@dbproject.dfs.core.windows.net/checkpoint_{p_file}").option("path", f"abfss://bronze@dbproject.dfs.core.windows.net/{p_file}").trigger(once=True).start()
